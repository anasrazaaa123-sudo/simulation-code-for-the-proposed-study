# %%
# Formula: y = 34.2332 + 7623 * x

# X کی 10 مختلف values
x_values = [748,978,1208,1438,1668,1898,2128,2358,2588,2818]

# Results calculate کریں
y_values = [-5.346 + 0.00005445 * x for x in x_values]

# Results print کریں
for i, x in enumerate(x_values):
   print('[', ','.join([str(round(y, 4)) for y in y_values]), ']')
# Out:
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]
# [ -5.3053,-5.2927,-5.2802,-5.2677,-5.2552,-5.2427,-5.2301,-5.2176,-5.2051,-5.1926 ]

# %%
# Formula: y = 34.2332 + 7623 * x

# X کی 10 مختلف values
x_values = [935,1224,1513,1802,2091,2380,2669,2958,3247,3536]

# Results calculate کریں
y_values = [-3.17 +  (-0.0002316) * x for x in x_values]

# Results print کریں
for i, x in enumerate(x_values):
   print('[', ','.join([str(round(y, 4)) for y in y_values]), ']')
# Out:
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]
# [ -3.3865,-3.4535,-3.5204,-3.5873,-3.6543,-3.7212,-3.7881,-3.8551,-3.922,-3.9889 ]

# %%
# Formula: y = 34.2332 + 7623 * x

# X کی 10 مختلف values
x_values = [3810,4986,6162,7338,8514,9690,10866,12042,13218,14394]

# Results calculate کریں
y_values = [2.176 + (-0.0002862) * x for x in x_values]

# Results print کریں
for i, x in enumerate(x_values):
   print('[', ','.join([str(round(y, 4)) for y in y_values]), ']')
# Out:
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]
# [ 1.0856,0.749,0.4124,0.0759,-0.2607,-0.5973,-0.9338,-1.2704,-1.607,-1.9436 ]

# %%
# Formula: y = 34.2332 + 7623 * x

# X کی 10 مختلف values
x_values = [296,389,482,575,668,761,854,947,1040,1133]

# Results calculate کریں
y_values = [2.176 + (-0.0002862) * x for x in x_values]

# Results print کریں
for i, x in enumerate(x_values):
   print('[', ','.join([str(round(y, 4)) for y in y_values]), ']')
# Out:
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]
# [ 2.0913,2.0647,2.0381,2.0114,1.9848,1.9582,1.9316,1.905,1.8784,1.8517 ]

# %%
# آپ کے 7 formulas
import math 
import numpy as np
def f1(x): return -5.346 + 0.00005445*x
def f2(x): return -3.17 +  -0.0002316*x
def f3(x): return 2.176 + -0.0002862*x
def f4(x): return 710.3 + 0.04379*x
def f5(x): return 2.197 + (-0.0006002)*x + 0.0000001*x**2   
def f6(x): return 46.87 * np.exp(0.0006577 * x)
def f7(x): return 14.2 * np.exp(0.0006334 * x)
# 1 quadratic


# آپ کے x values
x_values = [748,978,1208,1438,1668,1898,2128,2358,2588,2818]

# ہر formula کے results calculate کریں
results = []
for x in x_values:
    row = [f1(x), f2(x), f3(x), f4(x), f5(x), f6(x), f7(x)]
    results.append(row)
print("leemda 1")
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# leemda 1
# [ -5.3053, -5.2927, -5.2802, -5.2677, -5.2552, -5.2427, -5.2301, -5.2176, -5.2051, -5.1926 ]
# [ -3.3432, -3.3965, -3.4498, -3.503, -3.5563, -3.6096, -3.6628, -3.7161, -3.7694, -3.8226 ]
# [ 1.9619, 1.8961, 1.8303, 1.7644, 1.6986, 1.6328, 1.567, 1.5011, 1.4353, 1.3695 ]
# [ 743.0549, 753.1266, 763.1983, 773.27, 783.3417, 793.4134, 803.4851, 813.5568, 823.6285, 833.7002 ]
# [ 1.804, 1.7057, 1.6179, 1.5407, 1.4741, 1.4181, 1.3726, 1.3377, 1.3135, 1.2997 ]
# [ 76.6567, 89.1757, 103.7391, 120.681, 140.3896, 163.3169, 189.9885, 221.0158, 257.1104, 299.0995 ]
# [ 22.806, 26.3827, 30.5202, 35.3066, 40.8437, 47.2492, 54.6592, 63.2313, 73.1477, 84.6194 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.346 + 0.00001*x
def f2(x): return -3.17 +  -0.0001843*x
def f3(x): return 2.175 + (-0.0002277)*x
def f4(x): return 710.5 + (0.03485)*x
def f5(x): return 2.195  + ( -0.0004768)*x + 0.0000000825*x**2   
def f6(x): return 46.99* np.exp(0.0005234 * x)
def f7(x): return 14.23* np.exp(0.0005041 * x)

# x values
x_values = [935,1224,1513,1802,2091,2380,2669,2958,3247,3536]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)

print("lemmda 2")

# Print column-wise (LaTeX-ready)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# lemmda 2
# [ -5.3366, -5.3338, -5.3309, -5.328, -5.3251, -5.3222, -5.3193, -5.3164, -5.3135, -5.3106 ]
# [ -3.3423, -3.3956, -3.4488, -3.5021, -3.5554, -3.6086, -3.6619, -3.7152, -3.7684, -3.8217 ]
# [ 1.9621, 1.8963, 1.8305, 1.7647, 1.6989, 1.6331, 1.5673, 1.5015, 1.4357, 1.3699 ]
# [ 743.0847, 753.1564, 763.228, 773.2997, 783.3714, 793.443, 803.5146, 813.5863, 823.658, 833.7296 ]
# [ 1.8213, 1.735, 1.6625, 1.6037, 1.5587, 1.5275, 1.5101, 1.5065, 1.5166, 1.5406 ]
# [ 76.6549, 89.1728, 103.7349, 120.6751, 140.3816, 163.3062, 189.9744, 220.9976, 257.087, 299.0699 ]
# [ 22.7983, 26.3738, 30.51, 35.295, 40.8303, 47.2338, 54.6416, 63.2111, 73.1246, 84.5929 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.346 + 0.0000106*x
def f2(x): return -3.171  +  (-0.0000453)*x
def f3(x): return 2.175 + (-0.00005597)*x
def f4(x): return 710.4 + (0.008565)*x
def f5(x): return 2.195  + ( -0.0001172 ) *x + 0.00000000489 *x**2   
def f6(x): return 46.96* np.exp(0.0001286  * x)
def f7(x): return 14.22* np.exp(0.0001239 * x)

# x values
x_values = [3810,4986,6162,7338,8514,9690,10866,12042,13218,14394]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)

print("lemmda 3")

# Print column-wise (LaTeX-ready)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# lemmda 3
# [ -5.3056, -5.2931, -5.2807, -5.2682, -5.2558, -5.2433, -5.2308, -5.2184, -5.2059, -5.1934 ]
# [ -3.3436, -3.3969, -3.4501, -3.5034, -3.5567, -3.61, -3.6632, -3.7165, -3.7698, -3.823 ]
# [ 1.9618, 1.8959, 1.8301, 1.7643, 1.6985, 1.6327, 1.5668, 1.501, 1.4352, 1.3694 ]
# [ 743.0326, 753.1051, 763.1775, 773.25, 783.3224, 793.3949, 803.4673, 813.5397, 823.6122, 833.6846 ]
# [ 1.8195, 1.7322, 1.6585, 1.5983, 1.5516, 1.5185, 1.4989, 1.4928, 1.5002, 1.5212 ]
# [ 76.651, 89.1656, 103.7236, 120.6583, 140.358, 163.2741, 189.9316, 220.9414, 257.0141, 298.9764 ]
# [ 22.7988, 26.375, 30.512, 35.298, 40.8348, 47.24, 54.6499, 63.2221, 73.1388, 84.6111 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.345 + 0.00001349*x
def f2(x): return -3.174  +  ( -0.0005728)*x
def f3(x): return 2.172 + ( -0.0007077)*x
def f4(x): return 711 + (0.1083)*x
def f5(x): return 2.187  + ( -0.001474 ) *x + 0.000000797 *x**2   
def f6(x): return 47.36* np.exp(0.001627  * x)
def f7(x): return 14.34* np.exp(0.001567 * x)

# x values
x_values = [296,389,482,575,668,761,854,947,1040,1133]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)


print(" R lemmda 1")
# Print column-wise (LaTeX-ready)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
#  R lemmda 1
# [ -5.341, -5.3398, -5.3385, -5.3372, -5.336, -5.3347, -5.3335, -5.3322, -5.331, -5.3297 ]
# [ -3.3435, -3.3968, -3.4501, -3.5034, -3.5566, -3.6099, -3.6632, -3.7164, -3.7697, -3.823 ]
# [ 1.9625, 1.8967, 1.8309, 1.7651, 1.6993, 1.6334, 1.5676, 1.5018, 1.436, 1.3702 ]
# [ 743.0568, 753.1287, 763.2006, 773.2725, 783.3444, 793.4163, 803.4882, 813.5601, 823.632, 833.7039 ]
# [ 1.8205, 1.7342, 1.6617, 1.603, 1.558, 1.5268, 1.5095, 1.5059, 1.5161, 1.5401 ]
# [ 76.6592, 89.1822, 103.7508, 120.6994, 140.4166, 163.3549, 190.0403, 221.0849, 257.201, 299.217 ]
# [ 22.8028, 26.3803, 30.5189, 35.3069, 40.846, 47.2541, 54.6676, 63.2441, 73.1661, 84.6448 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.346 + 0.0001195*x
def f2(x): return -3.172  +  ( -0.0005074)*x
def f3(x): return 2.173 + (-0.0006268)*x
def f4(x): return 710.7  + (0.09593)*x
def f5(x): return 2.191  + ( -0.001309 ) *x + 0.000000625 *x**2   
def f6(x): return 47.17 * np.exp(0.001441  * x)
def f7(x): return 14.29* np.exp(0.001388 * x)

# x values
x_values = [337,442,547,652,757,862,967,1072,1177,1282]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)


print(" R lemmda 2")
# Print column-wise (LaTeX-ready)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
#  R lemmda 2
# [ -5.3057, -5.2932, -5.2806, -5.2681, -5.2555, -5.243, -5.2304, -5.2179, -5.2053, -5.1928 ]
# [ -3.343, -3.3963, -3.4495, -3.5028, -3.5561, -3.6094, -3.6627, -3.7159, -3.7692, -3.8225 ]
# [ 1.9618, 1.896, 1.8301, 1.7643, 1.6985, 1.6327, 1.5669, 1.5011, 1.4353, 1.3694 ]
# [ 743.0284, 753.1011, 763.1737, 773.2464, 783.319, 793.3917, 803.4643, 813.537, 823.6096, 833.6823 ]
# [ 1.8208, 1.7345, 1.662, 1.6032, 1.5582, 1.527, 1.5096, 1.506, 1.5161, 1.5401 ]
# [ 76.6596, 89.1821, 103.7501, 120.6978, 140.414, 163.3508, 190.0344, 221.0768, 257.19, 299.2023 ]
# [ 22.8127, 26.3919, 30.5326, 35.3231, 40.8651, 47.2766, 54.6941, 63.2754, 73.203, 84.6882 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.346 + 0.00003044*x
def f2(x): return -3.171  +  (  -0.0001293)*x
def f3(x): return 2.175 + (-0.0001597)*x
def f4(x): return 710.5  + (0.02444)*x
def f5(x): return 2.194  + ( -0.0003343) *x + 0.0000000406 *x**2   
def f6(x): return 47.01* np.exp(0.0003671  * x)
def f7(x): return 14.24* np.exp(0.0003535 * x)

# x values
x_values = [1332.25,1744.3327,2156.4157,2568.4987,2980.5817,3392.6647,3804.7477,4216.8307,4628.9137,5040.9967]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)


print("AZI")
# Print column-wise (LaTeX-ready)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# AZI
# [ -5.3054, -5.2929, -5.2804, -5.2678, -5.2553, -5.2427, -5.2302, -5.2176, -5.2051, -5.1926 ]
# [ -3.3433, -3.3965, -3.4498, -3.5031, -3.5564, -3.6097, -3.663, -3.7162, -3.7695, -3.8228 ]
# [ 1.9622, 1.8964, 1.8306, 1.7648, 1.699, 1.6332, 1.5674, 1.5016, 1.4358, 1.37 ]
# [ 743.0602, 753.1315, 763.2028, 773.2741, 783.3454, 793.4167, 803.488, 813.5593, 823.6307, 833.702 ]
# [ 1.8207, 1.7344, 1.6619, 1.6032, 1.5583, 1.5271, 1.5098, 1.5062, 1.5165, 1.5405 ]
# [ 76.6638, 89.1843, 103.7496, 120.6937, 140.4051, 163.3357, 190.0112, 221.0434, 257.1436, 299.1396 ]
# [ 22.8056, 26.3819, 30.519, 35.3048, 40.8412, 47.2457, 54.6546, 63.2253, 73.14, 84.6096 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.345 + 0.0002108*x
def f2(x): return -3.176   +  (-0.0008953)*x
def f3(x): return 2.168  + ( -0.001106 ) *x
def f4(x): return 711.5  + ( 0.1693) *x
def f5(x): return 2.181  + (  -0.002293) *x + 0.000001947 *x**2   
def f6(x): return 47.71* np.exp(0.002542  * x)
def f7(x): return 14.44* np.exp(0.002449 * x)

# x values
x_values = [186.5,246,305.5,365,424.5,484,543,603,662.5,722]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)

print("Rezg 2")

transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# Rezg 2
# [ -5.3057, -5.2931, -5.2806, -5.2681, -5.2555, -5.243, -5.2305, -5.2179, -5.2053, -5.1928 ]
# [ -3.343, -3.3962, -3.4495, -3.5028, -3.5561, -3.6093, -3.6621, -3.7159, -3.7691, -3.8224 ]
# [ 1.9617, 1.8959, 1.8301, 1.7643, 1.6985, 1.6327, 1.5674, 1.5011, 1.4353, 1.3695 ]
# [ 743.0744, 753.1478, 763.2211, 773.2945, 783.3678, 793.4412, 803.4299, 813.5879, 823.6612, 833.7346 ]
# [ 1.8211, 1.7347, 1.6622, 1.6034, 1.5585, 1.5273, 1.51, 1.5063, 1.5164, 1.5404 ]
# [ 76.648, 89.1636, 103.7228, 120.6593, 140.3613, 163.2804, 189.7006, 220.9568, 257.036, 299.0064 ]
# [ 22.7995, 26.376, 30.5136, 35.3001, 40.8376, 47.2436, 54.5877, 63.2281, 73.1465, 84.6208 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.346 + 0.0001195*x
def f2(x): return -3.169  +  (-0.00139)*x
def f3(x): return 2.177 + (-0.001717 ) *x
def f4(x): return 710.1  + (0.2628) *x
def f5(x): return 2.199  + ( -0.003608 ) *x + 0.000004692 *x**2   
def f6(x): return 46.74* np.exp(0.003947 * x)
def f7(x): return 14.16* np.exp(0.003801 * x)

# x values
x_values = [125.33,163.66,201.99,240.32,278.65,316.98,355.31,393.64,431.97,470.3]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)

print("Rezg 1")

# Print column-wise (LaTeX-ready)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# Rezg 1
# [ -5.331, -5.3264, -5.3219, -5.3173, -5.3127, -5.3081, -5.3035, -5.299, -5.2944, -5.2898 ]
# [ -3.3432, -3.3965, -3.4498, -3.503, -3.5563, -3.6096, -3.6629, -3.7162, -3.7694, -3.8227 ]
# [ 1.9618, 1.896, 1.8302, 1.7644, 1.6986, 1.6327, 1.5669, 1.5011, 1.4353, 1.3695 ]
# [ 743.0367, 753.1098, 763.183, 773.2561, 783.3292, 793.4023, 803.4755, 813.5486, 823.6217, 833.6948 ]
# [ 1.8205, 1.7342, 1.6617, 1.6029, 1.5579, 1.5268, 1.5094, 1.5058, 1.516, 1.5399 ]
# [ 76.6522, 89.1719, 103.7366, 120.6801, 140.3911, 163.3215, 189.9971, 221.0298, 257.1311, 299.1289 ]
# [ 22.8009, 26.377, 30.514, 35.2998, 40.8362, 47.241, 54.6503, 63.2216, 73.1373, 84.6082 ]

# %%
import mpmath  # Arbitrary-precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision

# Define formulas

import numpy as np
def f1(x): return -5.346 + 0.000008308*x
def f2(x): return -3.172   +  (-0.00003528 )*x
def f3(x): return  2.174  + ( -0.00004359 ) *x
def f4(x): return 710.6   + ( 0.006671) *x
def f5(x): return 2.192  + (  -0.00009112 ) *x + 0.000000003024 *x**2   
def f6(x): return 47.1* np.exp(0.0001002 * x)
def f7(x): return 14.25* np.exp(0.00009655 * x)

# x values
x_values = [4862,6372,7882,9392,10902,12412,13922,15432,16942,18452]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x), f5(x), f6(x),
        f7(x)
    ]
    results.append(row)

print("Rezg 3")

# Print column-wise (LaTeX-ready)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# Rezg 3
# [ -5.3056, -5.2931, -5.2805, -5.268, -5.2554, -5.2429, -5.2303, -5.2178, -5.2052, -5.1927 ]
# [ -3.3435, -3.3968, -3.4501, -3.5033, -3.5566, -3.6099, -3.6632, -3.7164, -3.7697, -3.823 ]
# [ 1.9621, 1.8962, 1.8304, 1.7646, 1.6988, 1.633, 1.5671, 1.5013, 1.4355, 1.3697 ]
# [ 743.0344, 753.1076, 763.1808, 773.254, 783.3272, 793.4005, 803.4737, 813.5469, 823.6201, 833.6933 ]
# [ 1.8205, 1.7342, 1.6617, 1.6029, 1.558, 1.5269, 1.5095, 1.506, 1.5162, 1.5403 ]
# [ 76.665, 89.1881, 103.7568, 120.7052, 140.4222, 163.3598, 190.0443, 221.0877, 257.2019, 299.2153 ]
# [ 22.7868, 26.3633, 30.5011, 35.2884, 40.8271, 47.235, 54.6487, 63.2261, 73.1496, 84.6307 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -5.706 + 0.08699 *x
def f2(x): return -1.423 +  (-0.411 )*x
def f3(x): return 4.283  + ( -0.498)*x
def f4(x): return 374.3  + ( 78.78)*x 

# 1 Quartic/Polynomial formula
def f5(x): return -1838  + ( 1433)*x + ( -416.9)*x**2 + 53.73*x**3 + (-2.589)*x**4

# 2 Exponential formulas
def f6(x): return 0.1899* np.exp(1.265  * x)
def f7(x): return 0.07331* np.exp(1.212* x)

# x values
x_values = [3.6792,3.9285,4.1281,4.2945,4.4371,4.5620,4.6730,4.7729,4.8637,4.9470]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print("Entropy lemmda 1 ")
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# Entropy lemmda 1
# [ -5.3859, -5.3643, -5.3469, -5.3324, -5.32, -5.3092, -5.2995, -5.2908, -5.2829, -5.2757 ]
# [ -2.9352, -3.0376, -3.1196, -3.188, -3.2466, -3.298, -3.3436, -3.3847, -3.422, -3.4562 ]
# [ 2.4508, 2.3266, 2.2272, 2.1443, 2.0733, 2.0111, 1.9558, 1.9061, 1.8609, 1.8194 ]
# [ 664.1474, 683.7872, 699.5117, 712.6207, 723.8547, 733.6944, 742.4389, 750.3091, 757.4623, 764.0247 ]
# [ -7.5355, -1.5793, 1.0223, 2.1764, 2.6612, 2.8287, 2.8473, 2.8017, 2.7344, 2.6664 ]
# [ 19.944, 27.3385, 35.1909, 43.4358, 52.0224, 60.9268, 70.1115, 79.556, 89.2394, 99.1563 ]
# [ 6.3353, 8.5701, 10.9157, 13.3548, 15.8744, 18.4689, 21.1284, 23.8479, 26.6222, 29.4503 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -5.706 + 0.08699 *x
def f2(x): return -1.423 +  (-0.411 )*x
def f3(x): return 4.283  + ( -0.498)*x
def f4(x): return 374.3  + ( 78.78)*x 

# 1 Quartic/Polynomial formula
def f5(x): return -1838  + ( 1433)*x + ( -416.9)*x**2 + 53.73*x**3 + (-2.589)*x**4

# 2 Exponential formulas
def f6(x): return 0.1899* np.exp(1.265  * x)
def f7(x): return 0.07331* np.exp(1.212* x)

# x values
x_values = [4.4900,4.7472,4.9517,5.1214,5.2665,5.3931,5.5056,5.6066,5.6984,5.7824]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print("entropy lemdda 2")
# Print each row in one line (rounded, ready for LaTeX)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# entropy lemdda 2
# [ -5.3154, -5.293, -5.2753, -5.2605, -5.2479, -5.2369, -5.2271, -5.2183, -5.2103, -5.203 ]
# [ -3.2684, -3.3741, -3.4581, -3.5279, -3.5875, -3.6396, -3.6858, -3.7273, -3.765, -3.7996 ]
# [ 2.047, 1.9189, 1.8171, 1.7325, 1.6603, 1.5972, 1.5412, 1.4909, 1.4452, 1.4034 ]
# [ 728.0222, 748.2844, 764.3949, 777.7639, 789.1949, 799.1684, 808.0312, 815.9879, 823.22, 829.8375 ]
# [ 2.7557, 2.8173, 2.6626, 2.5472, 2.4987, 2.495, 2.5076, 2.5123, 2.491, 2.4305 ]
# [ 55.6228, 77.0112, 99.7476, 123.6325, 148.5416, 174.3411, 201.0043, 228.3984, 256.523, 285.282 ]
# [ 16.9255, 23.1165, 29.6186, 36.3822, 43.3775, 50.571, 57.9586, 65.5059, 73.2152, 81.0617 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -5.969 + 0.0852 *x
def f2(x): return -0.1722   +  ( -0.4035 )*x
def f3(x): return 5.797  + (-0.4887 )*x
def f4(x): return 134.4  + (77.37)*x 

# 1 Quartic/Polynomial formula
def f5(x): return -1.1770  + ( 5641)*x + ( -1012)*x**2 + 80.57 *x**3 + (-2.403)*x**4

# 2 Exponential formulas
def f6(x): return 0.003942* np.exp(1.245 * x)
def f7(x): return 0.001796* np.exp(1.192* x)

# x values
x_values = [7.6685,7.9344,8.1442,8.3175,8.4652,8.5939,8.7078,8.8101,8.9029,8.9879]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print("entropy lemdda 3")
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# entropy lemdda 3
# [ -5.3156, -5.293, -5.2751, -5.2603, -5.2478, -5.2368, -5.2271, -5.2184, -5.2105, -5.2032 ]
# [ -3.2664, -3.3737, -3.4584, -3.5283, -3.5879, -3.6398, -3.6858, -3.7271, -3.7645, -3.7988 ]
# [ 2.0494, 1.9195, 1.8169, 1.7322, 1.6601, 1.5972, 1.5415, 1.4915, 1.4462, 1.4046 ]
# [ 727.7118, 748.2845, 764.5168, 777.925, 789.3525, 799.31, 808.1225, 816.0374, 823.2174, 829.7938 ]
# [ 11768.657, 11768.1598, 11767.5439, 11767.0381, 11766.6494, 11766.3429, 11766.0822, 11765.8373, 11765.5863, 11765.3134 ]
# [ 55.2139, 76.8812, 99.8293, 123.8685, 148.875, 174.7469, 201.37, 228.722, 256.7347, 285.3934 ]
# [ 16.7544, 23.0027, 29.5385, 36.3163, 43.3075, 50.488, 57.8298, 65.3296, 72.9711, 80.7521 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -5.167 + 0.08558 *x
def f2(x): return -3.969 +  (-0.4051)*x
def f3(x): return 1.198 + ( -0.4906)*x
def f4(x): return 862.5 + (77.67)*x 

# 1 Quartic/Polynomial formula
def f5(x): return -0.08944  + (  -8.079)*x + (  -14.02 )*x**2 + (-9.988)  *x**3 + (-2.441)*x**4

# 2 Exponential formulas
def f6(x): return 483.6* np.exp(0.001627   * x)
def f7(x): return 133.8* np.exp(1.196* x)

# x values
x_values = [-1.7346,-1.4707,-1.2620,-1.0895,-0.9423,-0.8141,-0.7004,-0.5984,-0.5058,-0.4211]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print(" Entropy Rlemmda 1")
# Print each row in one line (rounded, ready for LaTeX)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
#  Entropy Rlemmda 1
# [ -5.3154, -5.2929, -5.275, -5.2602, -5.2476, -5.2367, -5.2269, -5.2182, -5.2103, -5.203 ]
# [ -3.2663, -3.3732, -3.4578, -3.5276, -3.5873, -3.6392, -3.6853, -3.7266, -3.7641, -3.7984 ]
# [ 2.049, 1.9195, 1.8171, 1.7325, 1.6603, 1.5974, 1.5416, 1.4916, 1.4461, 1.4046 ]
# [ 727.7736, 748.2707, 764.4805, 777.8785, 789.3116, 799.2689, 808.0999, 816.0223, 823.2145, 829.7932 ]
# [ 1.7705, 1.8202, 1.6608, 1.5484, 1.507, 1.5126, 1.5358, 1.5519, 1.5428, 1.4956 ]
# [ 482.2371, 482.4442, 482.6081, 482.7435, 482.8592, 482.9599, 483.0492, 483.1294, 483.2022, 483.2688 ]
# [ 16.8065, 23.0436, 29.5769, 36.354, 43.3521, 50.5358, 57.8971, 65.409, 73.0694, 80.8593 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -5.253 + 0.08852 *x
def f2(x): return -3.562  +  (  -0.4173)*x
def f3(x): return 1.691 + ( -0.5058)*x
def f4(x): return 784.4  + (79.97)*x 

# 1 Quartic/Polynomial formula
def f5(x): return 1.521 + ( -0.2678)*x + (  1.382 )*x**2 + (-0.1703)  *x**3 + (-2.755)*x**4

# 2 Exponential formulas
def f6(x): return 138* np.exp(1.282   * x)
def f7(x): return 40.26* np.exp(1.228* x)

# x values
x_values = [-0.7015,-0.4515,-0.2514,-0.0847,0.0582,0.1833,0.2944,0.3945,0.4854,0.5688]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print(" Entropy Rlemmda 2")
# Print each row in one line (rounded, ready for LaTeX)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
#  Entropy Rlemmda 2
# [ -5.3151, -5.293, -5.2753, -5.2605, -5.2478, -5.2368, -5.2269, -5.2181, -5.21, -5.2026 ]
# [ -3.2693, -3.3736, -3.4571, -3.5267, -3.5863, -3.6385, -3.6849, -3.7266, -3.7646, -3.7994 ]
# [ 2.0458, 1.9194, 1.8182, 1.7338, 1.6616, 1.5983, 1.5421, 1.4915, 1.4455, 1.4033 ]
# [ 728.301, 748.2935, 764.2955, 777.6265, 789.0543, 799.0585, 807.9432, 815.9482, 823.2174, 829.8869 ]
# [ 1.7806, 1.8248, 1.6674, 1.5536, 1.51, 1.5142, 1.5369, 1.5532, 1.5442, 1.4961 ]
# [ 56.1446, 77.357, 99.9789, 123.8001, 148.6904, 174.5558, 201.2755, 228.8353, 257.1184, 286.1326 ]
# [ 17.012, 23.125, 29.5664, 36.2829, 43.2427, 50.4232, 57.7938, 65.3531, 73.0709, 80.9511 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -5.793 +  0.08614*x
def f2(x): return -1.008  +  (-0.4074)*x
def f3(x): return  4.785  + (-0.4935)*x
def f4(x): return 294.8   + (78.11)*x 

# 1 Quartic/Polynomial formula
def f5(x): return -3762  + ( 2425 )*x + ( -584.6 )*x**2 + (62.49)  *x**3 + (-2.499)*x**4

# 2 Exponential formulas
def f6(x): return 0.05253* np.exp(1.256   * x)
def f7(x): return 0.02142* np.exp(1.202* x)

# x values
x_values = [5.5449,5.8062,6.0132,6.1846,6.3309,	6.4586,6.5717,6.6734,6.7656,6.8501]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print("Entropy AZI")
# Print each row in one line (rounded, ready for LaTeX)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# Entropy AZI
# [ -5.3154, -5.2929, -5.275, -5.2603, -5.2477, -5.2367, -5.2269, -5.2182, -5.2102, -5.2029 ]
# [ -3.267, -3.3734, -3.4578, -3.5276, -3.5872, -3.6392, -3.6853, -3.7267, -3.7643, -3.7987 ]
# [ 2.0486, 1.9196, 1.8175, 1.7329, 1.6607, 1.5977, 1.5419, 1.4917, 1.4462, 1.4045 ]
# [ 727.9121, 748.3223, 764.4911, 777.8791, 789.3066, 799.2812, 808.1155, 816.0593, 823.261, 829.8613 ]
# [ 1.4715, 1.6112, 1.5306, 1.487, 1.5072, 1.5689, 1.6435, 1.7074, 1.7427, 1.7368 ]
# [ 55.5911, 77.1859, 100.1039, 124.1495, 149.1928, 175.1479, 201.8822, 229.3891, 257.5523, 286.3901 ]
# [ 16.8027, 23.0029, 29.5014, 36.2507, 43.2204, 50.3907, 57.7286, 65.235, 72.8805, 80.6719 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -4.806 + 0.0779 *x
def f2(x): return  -5.703 +  (-0.3727 )*x
def f3(x): return   -0.8966  + (   -0.4506)*x
def f4(x): return  1195  + (71.57)*x 

# 1 Quartic/Polynomial formula
def f5(x): return -1887 + (  -1322  )*x + ( -345.9 )*x**2 + (-40.1)  *x**3 + (-1.738)*x**4

# 2 Exponential formulas
def f6(x): return 108300* np.exp(1.162   * x)
def f7(x): return 23690* np.exp(1.111* x)

# x values
x_values = [-6.5560,-6.2505,-6.0164,-5.8267,-5.6672,-5.5297,-5.4087,-5.3008,-5.2034,-5.1147]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print("Entropy Rezg2")
# Print each row in one line (rounded, ready for LaTeX)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
# Entropy Rezg2
# [ -5.3167, -5.2929, -5.2747, -5.2599, -5.2475, -5.2368, -5.2273, -5.2189, -5.2113, -5.2044 ]
# [ -3.2596, -3.3734, -3.4607, -3.5314, -3.5908, -3.6421, -3.6872, -3.7274, -3.7637, -3.7968 ]
# [ 2.0575, 1.9199, 1.8144, 1.7289, 1.657, 1.5951, 1.5406, 1.4919, 1.4481, 1.4081 ]
# [ 725.7871, 747.6517, 764.4063, 777.9831, 789.3985, 799.2394, 807.8993, 815.6217, 822.5927, 828.9409 ]
# [ 1.6655, 1.8429, 1.7582, 1.7098, 1.7221, 1.7704, 1.8272, 1.8709, 1.8861, 1.8627 ]
# [ 53.2282, 75.9124, 99.644, 124.2176, 149.5116, 175.414, 201.8957, 228.8647, 256.29, 284.115 ]
# [ 16.2662, 22.8398, 29.6241, 36.5743, 43.6651, 50.8719, 58.1917, 65.6029, 73.1002, 80.6708 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return -5.996 + 0.08463  *x
def f2(x): return   -0.04211 +  (-0.4011 )*x
def f3(x): return   5.954  + ( -0.4857)*x
def f4(x): return   109.3  + (76.92  )*x 

# 1 Quartic/Polynomial formula
def f5(x): return -12690 + (  6278 )*x + ( -1078 )*x**2 + (  82.16 )  *x**3 + (-2.345)*x**4

# 2 Exponential formulas
def f6(x): return 0.002617* np.exp(1.239* x)
def f7(x): return 0.001214* np.exp(1.186* x)

# x values
x_values = [8.0372,8.3058,8.5174,8.6919,8.8404,8.9697,9.0842,9.1869,9.2800,9.3652]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print(" e   Rezg3")
# Print each row in one line (rounded, ready for LaTeX)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
#  e   Rezg3
# [ -5.3158, -5.2931, -5.2752, -5.2604, -5.2478, -5.2369, -5.2272, -5.2185, -5.2106, -5.2034 ]
# [ -3.2658, -3.3736, -3.4584, -3.5284, -3.588, -3.6399, -3.6858, -3.727, -3.7643, -3.7985 ]
# [ 2.0503, 1.9199, 1.8171, 1.7323, 1.6602, 1.5974, 1.5418, 1.4919, 1.4467, 1.4053 ]
# [ 727.5214, 748.1821, 764.4584, 777.8809, 789.3036, 799.2493, 808.0567, 815.9563, 823.1176, 829.6712 ]
# [ 1002.8715, 1003.0227, 1002.9582, 1002.9367, 1002.982, 1003.0696, 1003.1706, 1003.2608, 1003.3227, 1003.344 ]
# [ 55.2774, 77.1043, 100.2164, 124.4044, 149.5348, 175.5163, 202.2687, 229.7157, 257.8024, 286.505 ]
# [ 16.7481, 23.0311, 29.6008, 36.4069, 43.4182, 50.6141, 57.9759, 65.4855, 73.1305, 80.9064 ]

# %%
import mpmath  # High precision math for large exponentials
mpmath.mp.dps = 50  # Decimal precision
import numpy as np
# Define formulas

# 4 Linear formulas (example)
def f1(x): return  -3.731 + 0.1244 *x
def f2(x): return    -10.41  +  (-0.5589) *x
def f3(x): return  -6.674 + ( -0.6833) *x
def f4(x): return   2086  + (106.3) *x 

# 1 Quartic/Polynomial formula
def f5(x): return -192100.00  + ( -62850.00  )*x + ( -7707 )*x**2 + (  -419.9 )  *x**3 + (-8.576)*x**4

# 2 Exponential formulas
def f6(x): return 93080000000* np.exp(1.659 * x)
def f7(x): return 12010000000* np.exp(1.593* x)

# x values
x_values = [-12.7050,-12.5726,-12.4455,-12.3285,-12.2216,-12.1239,-12.0342,-11.9515,-11.8748,-11.8033]  # small to avoid overflow

# Calculate results row-wise
results = []
for x in x_values:
    row = [
        f1(x), f2(x), f3(x), f4(x),
        f5(x),
        f6(x), f7(x)
    ]
    results.append(row)
print(" E  Rezg1")
# Print each row in one line (rounded, ready for LaTeX)
transposed = list(map(list, zip(*results)))

# print transpose
for row in transposed:
    print('[', ', '.join([str(round(y,4)) for y in row]), ']')# Print in row-by-row format (ready for LaTeX)
# Out:
#  E  Rezg1
# [ -5.3115, -5.295, -5.2792, -5.2647, -5.2514, -5.2392, -5.2281, -5.2178, -5.2082, -5.1993 ]
# [ -3.3092, -3.3832, -3.4542, -3.5196, -3.5793, -3.634, -3.6841, -3.7303, -3.7732, -3.8131 ]
# [ 2.0073, 1.9169, 1.83, 1.7501, 1.677, 1.6103, 1.549, 1.4925, 1.4401, 1.3912 ]
# [ 735.4585, 749.5326, 763.0434, 775.4805, 786.8439, 797.2294, 806.7645, 815.5556, 823.7088, 831.3092 ]
# [ 48.9548, 48.6568, 48.2663, 47.917, 47.6499, 47.458, 47.3149, 47.1902, 47.0553, 46.8855 ]
# [ 65.309, 81.3517, 100.448, 121.9662, 145.6331, 171.2587, 198.738, 227.9638, 258.8974, 291.5031 ]
# [ 19.4908, 24.0673, 29.4686, 35.5061, 42.0979, 49.1872, 56.7426, 64.7327, 73.1454, 81.9696 ]
